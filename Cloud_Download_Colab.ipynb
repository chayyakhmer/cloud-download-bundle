# %% [markdown]
# # Cloud Download App - Colab Runner
#
# Run these cells after pushing this folder to GitHub. Use only files you own, public-domain torrents, Linux ISOs, or content you have permission to download/share.

# %%
# Change this to your repo URL
REPO_URL = "https://github.com/YOUR_NAME/YOUR_REPO.git"
APP_DIR = "/content/cloud-download-app"

# %%
# !rm -rf "$APP_DIR"
# !git clone "$REPO_URL" "$APP_DIR"

# %%
# %cd /content/cloud-download-app
# !bash colab_install.sh

# %%
# %cd /content/cloud-download-app
# !bash colab_start.sh

# %% [markdown]
# Run the next cell and keep it running. Open the `trycloudflare.com` URL that appears.

# %%
# %cd /content/cloud-download-app
# !bash colab_tunnel.sh

# %% [markdown]
# Optional logs:

# %%
# %cd /content/cloud-download-app
# !tail -n 80 -f logs/app.log logs/aria2.log logs/worker.log

# %% [markdown]
# Optional stop:

# %%
# %cd /content/cloud-download-app
# !bash colab_stop.sh
